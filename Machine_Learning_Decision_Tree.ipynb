# %% [markdown]
# <a href="https://colab.research.google.com/github/aarushisubedi01/Decision-Tree-on-Iris-Dataset/blob/main/Machine_Learning_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Machine Learning Examples of Decision Tree:

  # A decision tree can predict whether a customer will click on an ad based on their browsing history
  # and demographics

# Business Decision Examples of Decision Tree:

  # A company can make or use a decision tree to evaluate whether to invest in a new product or market
  # based on potential cost, benefits and risks.

# Pruning - Pruning decision tree involves removing branches or nodes to simplify the model
  # and to improvde it's generalization ablity and to prevent overfitting and enhancing predicitive
  # accuracy on unseen data.

  # Overfitting - Decision trees can become overly complex and learn to training data too well,
   # including noise and irrelavant details, leading to poor performance on maybe new data, unseen data.

   # Purning as solutions - It will addresses this by simplifying the tree, making it less prone to overfitting
    # and more robust. - Pre-Purning and Post-Purning

# Entropy -
  # Lower Entropy indicartes greater certainity in predicition leading to more accurate decision-making

# %% [markdown]
# ## **Implementation of Decision Tree**

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Feature Selection and Feature Engineering

X = df[iris.feature_names]
y = df['target']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X.head(1)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2

# %%
y.head(1)
# Out:
# 0    0
# Name: target, dtype: int64

# %%
model = DecisionTreeClassifier(criterion='gini', max_depth=3)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0])

# %%
# Evaluation
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
plt.figure(figsize=(12,8))
plot_tree(model, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
plt.show()

# %%
# Gini index is a measure of stastistical dispersion used to represent income inequality.

# scale - 0 to 1, 0% to 100%

# 0 - It represents perfect equality (Everyone has the some salary and life)
# 1 - It represents perfect inequality (one person has all the salary and life that other person wants)

# Higher Gini Coefficients values indicates the greater inequality while lower values indicates less inequality.

# 0.5 < Lower
# 0.5 >
